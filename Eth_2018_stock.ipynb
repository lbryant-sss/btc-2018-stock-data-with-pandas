# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
url = 'https://raw.githubusercontent.com/lbryant-sss/bitcoin_history_prices/main/bitcoin_cash_price.csv'
data = pd.read_csv(url)
data.head()
Dates = pd.to_datetime(data['Date'])
data.set_index(Dates, inplace=True)
data.head()
# Out:
#                     Date     Open  ...       Volume      Market Cap
# Date                               ...
# 2018-02-20  Feb 20, 2018  1543.27  ...  820,947,000  26,199,800,000
# 2018-02-19  Feb 19, 2018  1483.34  ...  578,906,000  25,179,700,000
# 2018-02-18  Feb 18, 2018  1552.10  ...  907,873,000  26,344,200,000
# 2018-02-17  Feb 17, 2018  1548.48  ...  641,719,000  26,280,100,000
# 2018-02-16  Feb 16, 2018  1373.16  ...  961,010,000  23,302,000,000
#
# [5 rows x 7 columns]

# %%
data.plot()

# %%
data['Close'].plot()

# %%
 
Highest = data['Close'].max()
print("Highest closing price")
print(Highest)
print("Highest volume")
data['Volume'].max()
# Out:
# Highest closing price
# 3923.07
# Highest volume
# '993,310,000'

# %%
data['High'].plot()

# %%
data['Low'].plot()
